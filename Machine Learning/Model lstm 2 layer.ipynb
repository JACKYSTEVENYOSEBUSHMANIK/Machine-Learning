# %%
# import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import balanced_accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.utils import to_categorical

from imblearn.over_sampling import SMOTE
from scipy.stats import mode

import tensorflow as tf
from tensorflow.keras.layers import Layer
import tensorflow.keras.backend as K

# --- Load data ---
df = pd.read_csv('data_3aktv.csv')

features = ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']

# --- Label Encoding ---
label_encoder = LabelEncoder()
df['encoded_activity'] = label_encoder.fit_transform(df['activity'])

X = df[features].values
y_encoded = df['encoded_activity'].values

# --- Sliding Window ---
def create_windows(X, y, window_size=100, step=50):
    Xs, ys = [], []
    for start in range(0, len(X) - window_size + 1, step):
        end = start + window_size
        Xs.append(X[start:end])
        window_labels = y[start:end]
        counts = np.bincount(window_labels)
        ys.append(np.argmax(counts))
    return np.array(Xs), np.array(ys)


X_windows, y_windows = create_windows(X, y_encoded)

# --- Split data sebelum normalisasi dan balancing ---
X_train, X_test, y_train, y_test = train_test_split(
    X_windows, y_windows, test_size=0.2, stratify=y_windows, random_state=42
)

# --- Normalisasi ---
scaler = StandardScaler()

# reshape ke 2D untuk fit scaler
X_train_shape = X_train.shape
X_train_2d = X_train.reshape(-1, X_train_shape[2])
X_train_2d = scaler.fit_transform(X_train_2d)
X_train = X_train_2d.reshape(X_train_shape)

X_test_shape = X_test.shape
X_test_2d = X_test.reshape(-1, X_test_shape[2])
X_test_2d = scaler.transform(X_test_2d)
X_test = X_test_2d.reshape(X_test_shape)

# --- SMOTE pada data train ---
X_train_flat = X_train.reshape((X_train.shape[0], -1))
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_flat, y_train)
X_train_resampled = X_train_resampled.reshape((-1, X_train_shape[1], X_train_shape[2]))

# --- 8. One-hot encoding label ---
num_classes = len(np.unique(y_train_resampled))
y_train_cat = to_categorical(y_train_resampled, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)


# --- 11. Buat model CNN-LSTM dengan Attention ---
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(X_train_resampled.shape[1], X_train_resampled.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(64, return_sequences=False))  # return_sequences=True agar bisa pakai Attention
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))


from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()

# --- 12. Callbacks untuk training ---
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')

# --- 13. Training ---
history = model.fit(
    X_train_resampled, y_train_cat,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, model_checkpoint],
    verbose=1
)

# --- 14. Visualisasi training ---
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Train')
plt.plot(history.history['val_accuracy'], label='Akurasi Val')
plt.title('Akurasi')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Train')
plt.plot(history.history['val_loss'], label='Loss Val')
plt.title('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# --- 15. Evaluasi model ---
y_pred = model.predict(X_test)
y_pred_class = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

print("=== Classification Report ===")
print(classification_report(y_true, y_pred_class, target_names=label_encoder.classes_))

# --- 16. Confusion Matrix ---
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred_class)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel("Prediksi")
plt.ylabel("Sebenarnya")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 128)            │          69,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 122,883 (480.01 KB)
#  Trainable params: 122,883 (480.01 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 418ms/step - accuracy: 0.5347 - loss: 0.9621 - val_accuracy: 0.6930 - val_loss: 0.5610
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.7653 - loss: 0.5266 - val_accuracy: 0.8947 - val_loss: 0.3397
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - accuracy: 0.9464 - loss: 0.2736 - val_accuracy: 1.0000 - val_loss: 0.0655
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9988 - loss: 0.0672 - val_accuracy: 0.9561 - val_loss: 0.1970
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - accuracy: 0.9579 - loss: 0.1786 - val_accuracy: 0.9123 - val_loss: 0.2988
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.9267 - loss: 0.2422 - val_accuracy: 0.9649 - val_loss: 0.1260
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - accuracy: 0.9896 - loss: 0.1228 - val_accuracy: 0.9912 - val_loss: 0.1064
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9960 - loss: 0.0860 - val_accuracy: 0.9912 - val_loss: 0.0712
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - accuracy: 0.9982 - loss: 0.0226 - val_accuracy: 0.9912 - val_loss: 0.0610
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9986 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9950 - loss: 0.0476 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.9982 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - accuracy: 0.9982 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.9990 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 0.9950 - loss: 0.0339 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.9986 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - accuracy: 0.9976 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9990 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9993 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - accuracy: 0.9990 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.9990 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 232ms/step - accuracy: 0.9982 - loss: 0.0128 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 232ms/step - accuracy: 0.9950 - loss: 0.0234 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.9986 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.9986 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9993 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9950 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 9.6314e-04
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9993 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 7.4156e-04
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.9681 - loss: 0.2296 - val_accuracy: 0.7018 - val_loss: 1.6250
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.7739 - loss: 0.9679 - val_accuracy: 0.9737 - val_loss: 0.1680
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9457 - loss: 0.2380 - val_accuracy: 0.9825 - val_loss: 0.1878
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9657 - loss: 0.1737 - val_accuracy: 1.0000 - val_loss: 0.1084
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9893 - loss: 0.1063 - val_accuracy: 1.0000 - val_loss: 0.0585
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9966 - loss: 0.0667 - val_accuracy: 1.0000 - val_loss: 0.0331
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9976 - loss: 0.0440 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9982 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9976 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9993 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0064
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
# === Classification Report ===
#               precision    recall  f1-score   support
#
#         diri       1.00      1.00      1.00        48
#        duduk       1.00      1.00      1.00        46
#        tidur       1.00      1.00      1.00        47
#
#     accuracy                           1.00       141
#    macro avg       1.00      1.00      1.00       141
# weighted avg       1.00      1.00      1.00       141

# %%
# Out:
# Label Classes: ['diri' 'duduk' 'tidur']
# Encoded Labels: [0 1 2]

# %%
# Simpan label encoder
import joblib

joblib.dump(label_encoder, 'label_encoder_new_3act.pkl')
# Out:
# ['label_encoder_new_3act.pkl']

# %%
# Simpan model CNN-LSTM dengan attention
model.save("model_cnn_lstm_attention_new_3act.h5")
print("✅ Model disimpan ke model_cnn_lstm_attention_6act.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model disimpan ke model_cnn_lstm_attention_6act.h5
